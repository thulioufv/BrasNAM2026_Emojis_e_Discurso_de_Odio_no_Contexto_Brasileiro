# %%
# Carregamento dos dados
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("youtube_emojis_olid-br_normalizado.csv")
df.head(20)
# Out:
#    emoji  freq_odio  freq_nao_odio  freq_total  freq_odio_norm  \
# 0      😏          1              0           1        0.000225
# 1      🎶          2              0           2        0.000449
# 2      🐂          1              0           1        0.000225
# 3      💃          1              0           1        0.000225
# 4      💫          1              0           1        0.000225
# 5      👈          1              1           2        0.000225
# 6      🤤          5              0           5        0.001123
# 7      🔞          1              0           1        0.000225
# 8      ✌          6              2           8        0.001348
# 9      🌳          1              0           1        0.000225
# 10     🙃          2              1           3        0.000449
# 11     ♥          1              1           2        0.000225
# 12     🔒          1              0           1        0.000225
# 13     👻          1              0           1        0.000225
# ...

# %%
# Selecionar colunas de frequência
dados_boxplot = df[[
    "freq_odio",
    "freq_nao_odio",
    "freq_total"
]]

# Estilo
sns.set(style="whitegrid")

# Criar figura
plt.figure(figsize=(10, 6))

# Boxplot
sns.boxplot(data=dados_boxplot)

# Título e labels
plt.title("Distribuição das Frequências dos Emojis", fontsize=14)
plt.ylabel("Frequência")
plt.xlabel("Categorias")

# Mostrar gráfico
plt.show()

# %%
# Quais emojis são mais usados no YouTube, independentemente de ódio?
df.sort_values("freq_total", ascending=False).head(15)
# Out:
#     emoji  freq_odio  freq_nao_odio  freq_total  freq_odio_norm  \
# 176     😂         44             13          57        0.009883
# 48      🤣         43              8          51        0.009659
# 128     ❤         14              8          22        0.003145
# 24      😡         17              3          20        0.003819
# 31      🤮         20              0          20        0.004492
# 166     🤦         16              3          19        0.003594
# 185     🏻         13              4          17        0.002920
# 19      🤬         15              1          16        0.003369
# 25      👏          8              7          15        0.001797
# 53      🏼         12              3          15        0.002695
# 181     ♀         11              3          14        0.002471
# 68      😭         12              2          14        0.002695
# 23      🤢         13              0          13        0.002920
# 152     🤡         11              2          13        0.002471
# ...

# %%
# Quais emojis são mais usados no YouTube em discurso de ódio?
df.sort_values("freq_odio", ascending=False).head(15)
# Out:
#     emoji  freq_odio  freq_nao_odio  freq_total  freq_odio_norm  \
# 176     😂         44             13          57        0.009883
# 48      🤣         43              8          51        0.009659
# 31      🤮         20              0          20        0.004492
# 24      😡         17              3          20        0.003819
# 166     🤦         16              3          19        0.003594
# 19      🤬         15              1          16        0.003369
# 128     ❤         14              8          22        0.003145
# 23      🤢         13              0          13        0.002920
# 185     🏻         13              4          17        0.002920
# 53      🏼         12              3          15        0.002695
# 68      😭         12              2          14        0.002695
# 66      🙄         11              1          12        0.002471
# 181     ♀         11              3          14        0.002471
# 152     🤡         11              2          13        0.002471
# ...

# %%
# Quais emojis são mais usados no YouTube em discurso de não ódio?
df.sort_values("freq_nao_odio", ascending=False).head(15)
# Out:
#     emoji  freq_odio  freq_nao_odio  freq_total  freq_odio_norm  \
# 176     😂         44             13          57        0.009883
# 48      🤣         43              8          51        0.009659
# 128     ❤         14              8          22        0.003145
# 25      👏          8              7          15        0.001797
# 76      🥰          6              6          12        0.001348
# 123     🙏          5              5          10        0.001123
# 161     👍          6              5          11        0.001348
# 146     🤷          3              4           7        0.000674
# 145     🏾          4              4           8        0.000898
# 84      ♂          8              4          12        0.001797
# 185     🏻         13              4          17        0.002920
# 40      🥺          3              3           6        0.000674
# 53      🏼         12              3          15        0.002695
# 181     ♀         11              3          14        0.002471
# ...

# %%
# Produção da razão ódio/não ódio no YouTube.

# Evitar divisão por zero
df_analise = df[(df["freq_odio_norm"] > 0) & (df["freq_nao_odio_norm"] > 0)]

df_analise["razao_odio_nao_odio"] = (
    df_analise["freq_odio_norm"] / df_analise["freq_nao_odio_norm"]
)

# Quais emojis possuem maior razão ódio/não ódio no Instagram?
df_analise.sort_values("razao_odio_nao_odio", ascending=False).head(20)
# Out:
#     emoji  freq_odio  freq_nao_odio  freq_total  freq_odio_norm  \
# 19      🤬         15              1          16        0.003369
# 66      🙄         11              1          12        0.002471
# 129     🏽         10              1          11        0.002246
# 182     😅          9              1          10        0.002022
# 68      😭         12              2          14        0.002695
# 24      😡         17              3          20        0.003819
# 152     🤡         11              2          13        0.002471
# 48      🤣         43              8          51        0.009659
# 166     🤦         16              3          19        0.003594
# 57      😍          9              2          11        0.002022
# 53      🏼         12              3          15        0.002695
# 181     ♀         11              3          14        0.002471
# 16      😒          7              2           9        0.001572
# 171     😉          7              2           9        0.001572
# ...

# %%
# Quais emojis são muito mais usados em ódio?
df_analise[df_analise["razao_odio_nao_odio"] > 2].sort_values(
    "razao_odio_nao_odio", ascending=False
).head(10)
# Out:
#    emoji  freq_odio  freq_nao_odio  freq_total  freq_odio_norm  \
# 19     🤬         15              1          16        0.003369
#
#     freq_nao_odio_norm  razao_odio_nao_odio
# 19            0.001312             2.567385

# %%
# Quais emojis são muito mais usados em não ódio?
df_analise[df_analise["razao_odio_nao_odio"] < 0.5].sort_values(
    "razao_odio_nao_odio"
).head(10)
# Out:
#     emoji  freq_odio  freq_nao_odio  freq_total  freq_odio_norm  \
# 121     🏿          1              3           4        0.000225
# 136     🤨          1              2           3        0.000225
# 160     😪          1              2           3        0.000225
# 146     🤷          3              4           7        0.000674
# 5       👈          1              1           2        0.000225
# 11      ♥          1              1           2        0.000225
# 80      😹          1              1           2        0.000225
# 58      😻          1              1           2        0.000225
# 120     😨          1              1           2        0.000225
# 126     😫          1              1           2        0.000225
#
#      freq_nao_odio_norm  razao_odio_nao_odio
# 121            0.003937             0.057053
# 136            0.002625             0.085580
# 160            0.002625             0.085580
# 146            0.005249             0.128369
# ...

# %%
# Muito mais em não ódio
df_analise[df_analise["razao_odio_nao_odio"] < 0.5].sort_values(
    "razao_odio_nao_odio"
).head(10)
# Out:
#     emoji  freq_odio  freq_nao_odio  freq_total  freq_odio_norm  \
# 121     🏿          1              3           4        0.000225
# 136     🤨          1              2           3        0.000225
# 160     😪          1              2           3        0.000225
# 146     🤷          3              4           7        0.000674
# 5       👈          1              1           2        0.000225
# 11      ♥          1              1           2        0.000225
# 80      😹          1              1           2        0.000225
# 58      😻          1              1           2        0.000225
# 120     😨          1              1           2        0.000225
# 126     😫          1              1           2        0.000225
#
#      freq_nao_odio_norm  razao_odio_nao_odio
# 121            0.003937             0.057053
# 136            0.002625             0.085580
# 160            0.002625             0.085580
# 146            0.005249             0.128369
# ...

# %%
df_analise.to_csv(
    "etapa1_youtube_emojis.csv",
    index=False,
    encoding="utf-8"
)
