# %%
# Carregamento dos dados
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("instagram_emojis_normalizado.csv")
df.head(20)
# Out:
#    emoji  freq_odio  freq_nao_odio  freq_total  freq_odio_norm  \
# 0      👸          0              1           1        0.000000
# 1      🩷          0              1           1        0.000000
# 2      😜          0              1           1        0.000000
# 3      🍭          0              1           1        0.000000
# 4      🪽          0              2           2        0.000000
# 5      💗          1              5           6        0.000286
# 6      🤑          2              1           3        0.000571
# 7      🤐          0              1           1        0.000000
# 8      ✈          0              1           1        0.000000
# 9      👪          0              1           1        0.000000
# 10     😮          3              2           5        0.000857
# 11     😠         23              5          28        0.006571
# 12     💛          3             34          37        0.000857
# 13     💝          0              2           2        0.000000
# 14     👇          1              0           1        0.000286
# 15     😨          1              2           3        0.000286
# 16     😞          0              3           3        0.000000
# 17     🍷          0              2           2        0.000000
# 18     ⭐          0              3           3        0.000000
# 19     🐴          3              1           4        0.000857
#
#     freq_nao_odio_norm
# 0             0.000286
# 1             0.000286
# 2             0.000286
# 3             0.000286
# 4             0.000571
# 5             0.001429
# 6             0.000286
# 7             0.000286
# 8             0.000286
# 9             0.000286
# 10            0.000571
# 11            0.001429
# 12            0.009714
# 13            0.000571
# 14            0.000000
# 15            0.000571
# 16            0.000857
# 17            0.000571
# 18            0.000857
# 19            0.000286

# %%
# Selecionar colunas de frequência
dados_boxplot = df[[
    "freq_odio",
    "freq_nao_odio",
    "freq_total"
]]

# Estilo
sns.set(style="whitegrid")

# Criar figura
plt.figure(figsize=(10, 6))

# Boxplot
sns.boxplot(data=dados_boxplot)

# Título e labels
plt.title("Distribuição das Frequências dos Emojis", fontsize=14)
plt.ylabel("Frequência")
plt.xlabel("Categorias")

# Mostrar gráfico
plt.show()

# %%
# Quais emojis são mais usados no Instagram, independentemente de ódio?
df.sort_values("freq_total", ascending=False).head(15)
# Out:
#     emoji  freq_odio  freq_nao_odio  freq_total  freq_odio_norm  \
# 99      👏         45            504         549        0.012857
# 193     ❤         11            255         266        0.003143
# 244     😂        117             61         178        0.033429
# 26      😍          5            136         141        0.001429
# 50      🙏         21            110         131        0.006000
# 126     🙌         15             87         102        0.004286
# 174     🤮         83              6          89        0.023714
# 64      🏻         21             52          73        0.006000
# 208     💚          5             52          57        0.001429
# 34      💩         51              1          52        0.014571
# 37      😡         42              6          48        0.012000
# 124     😢         20             26          46        0.005714
# 187     🤣         35             10          45        0.010000
# 159     🏼         11             26          37        0.003143
# 12      💛          3             34          37        0.000857
#
#      freq_nao_odio_norm
# 99             0.144000
# 193            0.072857
# 244            0.017429
# 26             0.038857
# 50             0.031429
# 126            0.024857
# 174            0.001714
# 64             0.014857
# 208            0.014857
# 34             0.000286
# 37             0.001714
# 124            0.007429
# 187            0.002857
# 159            0.007429
# 12             0.009714

# %%
# Quais emojis são mais usados no Instagram em discurso de ódio?
df.sort_values("freq_odio", ascending=False).head(15)
# Out:
#     emoji  freq_odio  freq_nao_odio  freq_total  freq_odio_norm  \
# 244     😂        117             61         178        0.033429
# 174     🤮         83              6          89        0.023714
# 34      💩         51              1          52        0.014571
# 99      👏         45            504         549        0.012857
# 37      😡         42              6          48        0.012000
# 187     🤣         35             10          45        0.010000
# 11      😠         23              5          28        0.006571
# 252     🤦         23             10          33        0.006571
# 64      🏻         21             52          73        0.006000
# 50      🙏         21            110         131        0.006000
# 124     😢         20             26          46        0.005714
# 126     🙌         15             87         102        0.004286
# 179     👊         14             16          30        0.004000
# 158     🤬         13              2          15        0.003714
# 81      👉         13              8          21        0.003714
#
#      freq_nao_odio_norm
# 244            0.017429
# 174            0.001714
# 34             0.000286
# 99             0.144000
# 37             0.001714
# 187            0.002857
# 11             0.001429
# 252            0.002857
# 64             0.014857
# 50             0.031429
# 124            0.007429
# 126            0.024857
# 179            0.004571
# 158            0.000571
# 81             0.002286

# %%
# Quais emojis são mais usados no Instagram em discurso de não ódio?
df.sort_values("freq_nao_odio", ascending=False).head(15)
# Out:
#     emoji  freq_odio  freq_nao_odio  freq_total  freq_odio_norm  \
# 99      👏         45            504         549        0.012857
# 193     ❤         11            255         266        0.003143
# 26      😍          5            136         141        0.001429
# 50      🙏         21            110         131        0.006000
# 126     🙌         15             87         102        0.004286
# 244     😂        117             61         178        0.033429
# 64      🏻         21             52          73        0.006000
# 208     💚          5             52          57        0.001429
# 12      💛          3             34          37        0.000857
# 73      👍          3             30          33        0.000857
# 124     😢         20             26          46        0.005714
# 159     🏼         11             26          37        0.003143
# 70      💪          4             22          26        0.001143
# 129     😘          4             21          25        0.001143
# 125     💙          2             19          21        0.000571
#
#      freq_nao_odio_norm
# 99             0.144000
# 193            0.072857
# 26             0.038857
# 50             0.031429
# 126            0.024857
# 244            0.017429
# 64             0.014857
# 208            0.014857
# 12             0.009714
# 73             0.008571
# 124            0.007429
# 159            0.007429
# 70             0.006286
# 129            0.006000
# 125            0.005429

# %%
# Produção da razão ódio/não ódio no Instagram.

# Evitar divisão por zero
df_analise = df[(df["freq_odio_norm"] > 0) & (df["freq_nao_odio_norm"] > 0)]

df_analise["razao_odio_nao_odio"] = (
    df_analise["freq_odio_norm"] / df_analise["freq_nao_odio_norm"]
)

# Quais emojis possuem maior razão ódio/não ódio no Instagram?
df_analise.sort_values("razao_odio_nao_odio", ascending=False).head(20)
# Out:
#     emoji  freq_odio  freq_nao_odio  freq_total  freq_odio_norm  \
# 34      💩         51              1          52        0.014571
# 174     🤮         83              6          89        0.023714
# 112     😤          7              1           8        0.002000
# 37      😡         42              6          48        0.012000
# 158     🤬         13              2          15        0.003714
# 93      👹          6              1           7        0.001714
# 128     😅          5              1           6        0.001429
# 11      😠         23              5          28        0.006571
# 249     👎         13              3          16        0.003714
# 43      ♂         13              3          16        0.003714
# 80      😬          4              1           5        0.001143
# 130     🤪          4              1           5        0.001143
# 222     😒         12              3          15        0.003429
# 187     🤣         35             10          45        0.010000
# 19      🐴          3              1           4        0.000857
# 22      🙈          3              1           4        0.000857
# 170     😕          3              1           4        0.000857
# 146     🧐          3              1           4        0.000857
# 215     🐷          3              1           4        0.000857
# 183     🤢         12              4          16        0.003429
#
#      freq_nao_odio_norm  razao_odio_nao_odio
# 34             0.000286            51.000000
# 174            0.001714            13.833333
# 112            0.000286             7.000000
# 37             0.001714             7.000000
# 158            0.000571             6.500000
# 93             0.000286             6.000000
# 128            0.000286             5.000000
# 11             0.001429             4.600000
# 249            0.000857             4.333333
# 43             0.000857             4.333333
# 80             0.000286             4.000000
# 130            0.000286             4.000000
# 222            0.000857             4.000000
# 187            0.002857             3.500000
# 19             0.000286             3.000000
# 22             0.000286             3.000000
# 170            0.000286             3.000000
# 146            0.000286             3.000000
# 215            0.000286             3.000000
# 183            0.001143             3.000000

# %%
# Quais emojis são muito mais usados em ódio?
df_analise[df_analise["razao_odio_nao_odio"] > 2].sort_values(
    "razao_odio_nao_odio", ascending=False
).head(10)
# Out:
#     emoji  freq_odio  freq_nao_odio  freq_total  freq_odio_norm  \
# 34      💩         51              1          52        0.014571
# 174     🤮         83              6          89        0.023714
# 112     😤          7              1           8        0.002000
# 37      😡         42              6          48        0.012000
# 158     🤬         13              2          15        0.003714
# 93      👹          6              1           7        0.001714
# 128     😅          5              1           6        0.001429
# 11      😠         23              5          28        0.006571
# 43      ♂         13              3          16        0.003714
# 249     👎         13              3          16        0.003714
#
#      freq_nao_odio_norm  razao_odio_nao_odio
# 34             0.000286            51.000000
# 174            0.001714            13.833333
# 112            0.000286             7.000000
# 37             0.001714             7.000000
# 158            0.000571             6.500000
# 93             0.000286             6.000000
# 128            0.000286             5.000000
# 11             0.001429             4.600000
# 43             0.000857             4.333333
# 249            0.000857             4.333333

# %%
# Quais emojis são muito mais usados em não ódio?
df_analise[df_analise["razao_odio_nao_odio"] < 0.5].sort_values(
    "razao_odio_nao_odio"
).head(10)
# Out:
#     emoji  freq_odio  freq_nao_odio  freq_total  freq_odio_norm  \
# 26      😍          5            136         141        0.001429
# 193     ❤         11            255         266        0.003143
# 25      💕          1             17          18        0.000286
# 12      💛          3             34          37        0.000857
# 99      👏         45            504         549        0.012857
# 208     💚          5             52          57        0.001429
# 54      💜          1             10          11        0.000286
# 73      👍          3             30          33        0.000857
# 125     💙          2             19          21        0.000571
# 57      🌷          1              6           7        0.000286
#
#      freq_nao_odio_norm  razao_odio_nao_odio
# 26             0.038857             0.036765
# 193            0.072857             0.043137
# 25             0.004857             0.058824
# 12             0.009714             0.088235
# 99             0.144000             0.089286
# 208            0.014857             0.096154
# 54             0.002857             0.100000
# 73             0.008571             0.100000
# 125            0.005429             0.105263
# 57             0.001714             0.166667
