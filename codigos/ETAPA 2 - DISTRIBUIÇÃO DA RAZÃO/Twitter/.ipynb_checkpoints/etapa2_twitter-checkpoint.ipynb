# %%
# Carregamento dos dados
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt

df = pd.read_csv("etapa1_twitter_emojis.csv")
df.head()
# Out:
#   emoji  freq_odio  freq_nao_odio  freq_total  freq_odio_norm  \
# 0     🔄          1              2           3        0.000069
# 1     😴          2              5           7        0.000138
# 2     😆          1              6           7        0.000069
# 3     🐷          1              3           4        0.000069
# 4     🎉          2              9          11        0.000138
#
#    freq_nao_odio_norm  razao_odio_nao_odio
# 0            0.000307             0.224538
# 1            0.000768             0.179630
# 2            0.000922             0.074846
# 3            0.000461             0.149692
# 4            0.001383             0.099795

# %%
# Gráfico contendo as distribuições da razão ódio/não ódio no Twitter
plt.rcParams["font.family"] = "serif"
plt.rcParams["font.serif"] = ["Times New Roman", "Times", "DejaVu Serif"]

plt.figure(figsize=(8,5), dpi=300)
plt.hist(df["razao_odio_nao_odio"], bins=25, color="#3B6922", edgecolor="black", alpha=0.7)
plt.axvline(1, color="red", linestyle="--", label="Razão = 1 (neutra)")

plt.xlim(0.0, 2.0)
plt.xticks([0.0, 0.5, 1.0, 1.5, 2.0])

plt.ylim(0, 50)
plt.yticks([0, 10, 20, 30, 40, 50])

plt.xlabel("Razão Ódio / Não Ódio (suavizada)", fontsize=16)
plt.ylabel("Número de emojis", fontsize=16)
plt.legend()
plt.show()
