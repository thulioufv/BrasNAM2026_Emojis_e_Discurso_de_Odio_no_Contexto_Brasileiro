# %%
# Carregamento dos dados
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv("etapa1_instagram_emojis.csv")
df.head()
# Out:
#   emoji  freq_odio  freq_nao_odio  freq_total  freq_odio_norm  \
# 0     💗          1              5           6        0.000286
# 1     🤑          2              1           3        0.000571
# 2     😮          3              2           5        0.000857
# 3     😠         23              5          28        0.006571
# 4     💛          3             34          37        0.000857
#
#    freq_nao_odio_norm  razao_odio_nao_odio
# 0            0.001429             0.200000
# 1            0.000286             2.000000
# 2            0.000571             1.500000
# 3            0.001429             4.600000
# 4            0.009714             0.088235

# %%
# Gráfico contendo as distribuições da razão ódio/não ódio no Instagram
bins = np.linspace(0, 2, 80)

plt.rcParams["font.family"] = "serif"
plt.rcParams["font.serif"] = ["Times New Roman", "Times", "DejaVu Serif"]

plt.figure(figsize=(8,5), dpi=300)
plt.hist(df["razao_odio_nao_odio"], bins=250, color="#8DF255", edgecolor="black", alpha=0.7)
plt.axvline(1, color="red", linestyle="--", label="Razão = 1 (neutra)")

plt.xlim(0.0, 2.0)
plt.xticks([0.0, 0.5, 1.0, 1.5, 2.0])

plt.ylim(0, 50)
plt.yticks([0, 10, 20, 30, 40, 50])

plt.xlabel("Razão Ódio / Não Ódio (suavizada)", fontsize=16)
plt.ylabel("Número de emojis", fontsize=16)
plt.legend()
plt.show()
